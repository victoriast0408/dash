# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('BillsJan.csv', decimal=',')

# %%
df.head()
# Out:
#          date  bill_number   total  paid_cash  paid_card  paid_customer_card  \
# 0  01.01.2018        34634   21.27        NaN      21.27                 NaN
# 1  01.01.2018        34845  105.56     105.56        NaN                 NaN
# 2  01.01.2018        35015    5.20        NaN        NaN                 5.2
# 3  01.01.2018        35115   26.28        NaN      26.28                 NaN
# 4  01.01.2018        35125   95.26      95.26        NaN                 NaN
#
#    user
# 0  Anna
# 1  Anna
# 2  Alex
# 3  Alex
# 4  Alex

# %%
total_for_anna = df.groupby('user')['total'].sum()

# %%
total_for_anna
# Out:
# user
# Alex     36132.55
# Anna      6788.61
# Marie    16401.59
# Name: total, dtype: float64
